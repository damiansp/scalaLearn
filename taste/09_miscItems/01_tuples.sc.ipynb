// %%
class Person(var name: String)
// Out:
// defined class Person

// %%
class SomeThings(i: Int, s: String, p: Person)
// Out:
// defined class SomeThings

// %%
val t = (3, "Three", new Person("Al"))
// Out:
// t: (Int, String, Person) = (
//   3,
//   "Three",
//   ammonite.$sess.cmd0$Helper$Person@e00e039
// )

// %%
val d = ("Maggie", 30)
// Out:
// d: (String, Int) = ("Maggie", 30)

// %%
t._1
// Out:
// res4: Int = 3

// %%
t._2
// Out:
// res5: String = "Three"

// %%
t._3
// Out:
// res6: Person = ammonite.$sess.cmd0$Helper$Person@e00e039

// %%
val (x, y, z) = (7, "Seven", new Person("Seven of Nine"))
// Out:
// x: Int = 7
// y: String = "Seven"
// z: Person = ammonite.$sess.cmd0$Helper$Person@2f9b49a0

// %%
x
// Out:
// res8: Int = 7

// %%
y
// Out:
// res9: String = "Seven"

// %%
def getStockInfo = {
    //...
    ("NFLX", 100.0, 101.0)
}
// Out:
// defined function getStockInfo

// %%
val (symbol, ask, bid) = getStockInfo
// Out:
// symbol: String = "NFLX"
// ask: Double = 100.0
// bid: Double = 101.0
