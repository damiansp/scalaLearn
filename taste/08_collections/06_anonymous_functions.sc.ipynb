// %%
val ints = List(1, 2, 3)
// Out:
// ints: List[Int] = List(1, 2, 3)

// %%
val ints = List.range(1, 10)
// Out:
// ints: List[Int] = List(1, 2, 3, 4, 5, 6, 7, 8, 9)

// %%
val doubledInts = ints.map(_ * 2)
// Out:
// doubledInts: List[Int] = List(2, 4, 6, 8, 10, 12, 14, 16, 18)

// %%
val doubledInts = ints.map(i => i * 2)
// Out:
// doubledInts: List[Int] = List(2, 4, 6, 8, 10, 12, 14, 16, 18)

// %%
val doubledInts = ints.map((i: Int) => i * 2)
// Out:
// doubledInts: List[Int] = List(2, 4, 6, 8, 10, 12, 14, 16, 18)

// %%
val doubledInts = for (i <- ints) yield i * 2
// Out:
// doubledInts: List[Int] = List(2, 4, 6, 8, 10, 12, 14, 16, 18)

// %%
val x = ints.filter(_ > 5)
// Out:
// x: List[Int] = List(6, 7, 8, 9)

// %%
val x = ints.filter(_ % 2 == 0)
// Out:
// x: List[Int] = List(2, 4, 6, 8)

// %%
val ints = List(1, 2, 3)

def double(i: Int): Int = 2 * i

val doubledInts = ints.map(double)
// Out:
// ints: List[Int] = List(1, 2, 3)
// defined function double
// doubledInts: List[Int] = List(2, 4, 6)

// %%
def lessThan5(i: Int): Boolean = if (i < 5) true else false
// Out:
// defined function lessThan5

// %%
val y = ints.filter(lessThan5)
// Out:
// y: List[Int] = List(1, 2, 3)
