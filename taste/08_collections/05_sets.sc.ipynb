// %%
import scala.collection.mutable.Set
// Out:
// import scala.collection.mutable.Set

// %%
val set = collection.mutable.Set[Int]()
// Out:
// set: Set[Int] = HashSet()

// %%
set += 1
set += 2 += 3
set ++= Vector(4, 5)
// Out:
// res3_0: Set[Int] = HashSet(1, 2, 3, 4, 5)
// res3_1: Set[Int] = HashSet(1, 2, 3, 4, 5)
// res3_2: Set[Int] = HashSet(1, 2, 3, 4, 5)

// %%
set += 2
// Out:
// res4: Set[Int] = HashSet(1, 2, 3, 4, 5)

// %%
set.add(6)
// Out:
// res5: Boolean = true

// %%
set
// Out:
// res6: Set[Int] = HashSet(1, 2, 3, 4, 5, 6)

// %%
set.add(6)
// Out:
// res7: Boolean = false

// %%
set -= 1
set -= (2, 3)
// Out:
// res8_0: Set[Int] = HashSet(4, 5, 6)
// res8_1: Set[Int] = HashSet(4, 5, 6)

// %%
set --= Array(4, 6)
// Out:
// res9: Set[Int] = HashSet(5)

// %%
set.remove(5)
// Out:
// res10: Boolean = true

// %%
set.clear()

// %%
set
// Out:
// res12: Set[Int] = HashSet()

// %%
set.remove(8)
// Out:
// res13: Boolean = false
