// %%
val ints = List(1, 2, 3)
val names = List("Ada", "Bob", "Dan")
// Out:
// ints: List[Int] = List(1, 2, 3)
// names: List[String] = List("Ada", "Bob", "Dan")

// %%
val ints: List[Int] = List(1, 2, 3)
val names: List[String] = List("Ada", "Bob", "Dan")
// Out:
// ints: List[Int] = List(1, 2, 3)
// names: List[String] = List("Ada", "Bob", "Dan")

// %%
val b = 0 +: ints
// Out:
// b: List[Int] = List(0, 1, 2, 3)

// %%
val c = List(-1, 0) ++: ints
// Out:
// c: List[Int] = List(-1, 0, 1, 2, 3)

// %%
val c2 = ints :++ List(4, 5)
// Out:
// c2: List[Int] = List(1, 2, 3, 4, 5)

// %%
for (name <- names) println(name)
// Out:
// Ada
// Bob
// Dan

// %%
val list = 1 :: 2 :: 3 :: Nil
// Out:
// list: List[Int] = List(1, 2, 3)
