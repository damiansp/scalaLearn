// %%
val s = "hello"
var i = 42
// Out:
// s: String = "hello"
// i: Int = 42

// %%
val count: Int = 1
val name: String = "Alvin"
// Out:
// count: Int = 1
// name: String = "Alvin"

// %%
val firstName = "John"
val mi = 'C'
val surname = "Doe"
// Out:
// firstName: String = "John"
// mi: Char = 'C'
// surname: String = "Doe"

// %%
val fullName = firstName + " " + mi + " " + surname
// Out:
// fullName: String = "John C Doe"

// %%
val name = s"$firstName $mi $surname"
// Out:
// name: String = "John C Doe"

// %%
println(s"Name: ${firstName} ${mi}. ${surname}")
// Out:
// Name: John C. Doe

// %%
println(s"1 + 1 = ${1 + 1}")
// Out:
// 1 + 1 = 2

// %%
val speech = """Four score and
seven years ago
our fathers..."""

println(speech)
// Out:
// Four score and
// seven years ago
// our fathers...
// speech: String = """Four score and
// seven years ago
// our fathers..."""

// %%
val getty = """Four score and
               |seven years ago
               |our fathers""".stripMargin
println(getty)
// Out:
// Four score and
// seven years ago
// our fathers
// getty: String = """Four score and
// seven years ago
// our fathers"""
