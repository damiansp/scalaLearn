// %%
def double(a: Int) = 2 * a
// Out:
// defined function double

// %%
double(20)
// Out:
// res2: Int = 40

// %%
def dub(a: Int): Int = 2 * a
// Out:
// defined function dub

// %%
dub(6)
// Out:
// res4: Int = 12

// %%
def add(a: Int, b: Int): Int = a + b
// Out:
// defined function add

// %%
add(3, 7)
// Out:
// res6: Int = 10

// %%
def addAndDub(a: Int, b: Int): Int = {
    val sum = a + b
    2 * sum
}
// Out:
// defined function addAndDub

// %%
addAndDub(3, 7)
// Out:
// res8: Int = 20
