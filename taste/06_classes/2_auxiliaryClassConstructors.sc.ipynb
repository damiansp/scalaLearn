// %%
val DefaultCrustSize = 12
val DefaultCrustType = "THIN"

// Primary constructor
class Pizza(crustSize: Int, crustType: String) {
    // 1-arg aux constructor
    def this(crustSize: Int) = {
        this(crustSize, DefaultCrustType)
    }
    
    // aux
    def this(crustType: String) = {
        this(DefaultCrustSize, crustType)
    }
    
    // aux
    def this() = {
        this(DefaultCrustSize, DefaultCrustType)
    }
    
    override def toString = {
        s"A $crustSize-inch pizza with $crustType crust"
    }
}
// Out:
// DefaultCrustSize: Int = 12
// DefaultCrustType: String = "THIN"
// defined class Pizza

// %%
val p1 = new Pizza(16, "THICK")
// Out:
// p1: Pizza = A 16-inch pizza with THICK crust

// %%
val p2 = new Pizza(14)
// Out:
// p2: Pizza = A 14-inch pizza with THIN crust

// %%
val p3 = new Pizza("STUFFED")
// Out:
// p3: Pizza = A 12-inch pizza with STUFFED crust

// %%
val p4 = new Pizza()
// Out:
// p4: Pizza = A 12-inch pizza with THIN crust

// %%
class Socket(var timeout: Int=2000, var linger: Int=3000) {
    override def toString = s"timeout: $timeout, linger: $linger"
}
// Out:
// defined class Socket

// %%
new Socket()
// Out:
// res6: Socket = timeout: 2000, linger: 3000

// %%
new Socket(1000)
// Out:
// res7: Socket = timeout: 1000, linger: 3000

// %%
new Socket(4000, 5000)
// Out:
// res8: Socket = timeout: 4000, linger: 5000

// %%
new Socket(linger=2000)
// Out:
// res9: Socket = timeout: 2000, linger: 2000
