// %%
sealed trait DayOfWeek
case object Sunday extends DayOfWeek
case object Monday extends DayOfWeek
case object Tuesday extends DayOfWeek
case object Wednesday extends DayOfWeek
case object Thursday extends DayOfWeek
case object Friday extends DayOfWeek
case object Saturday extends DayOfWeek
// Out:
// defined trait DayOfWeek
// defined object Sunday
// defined object Monday
// defined object Tuesday
// defined object Wednesday
// defined object Thursday
// defined object Friday
// defined object Saturday

// %%
sealed trait Suit
case object Spades extends Suit
case object Hearts extends Suit
case object Clubs extends Suit
case object Diamonds extends Suit
// Out:
// defined trait Suit
// defined object Spades
// defined object Hearts
// defined object Clubs
// defined object Diamonds

// %%
sealed trait Topping
case object Cheese extends Topping
case object Onions extends Topping
case object Sausage extends Topping
case object Mushrooms extends Topping
case object Pepperoni extends Topping
// Out:
// defined trait Topping
// defined object Cheese
// defined object Onions
// defined object Sausage
// defined object Mushrooms
// defined object Pepperoni

// %%
sealed trait CrustSize
case object SmallCrust extends CrustSize
case object MediumCrust extends CrustSize
case object LargeCrust extends CrustSize

sealed trait CrustType
case object ThinCrust extends CrustType
case object ThickCrust extends CrustType
case object SturffedCrust extends CrustType
// Out:
// defined trait CrustSize
// defined object SmallCrust
// defined object MediumCrust
// defined object LargeCrust
// defined trait CrustType
// defined object ThinCrust
// defined object ThickCrust
// defined object SturffedCrust

// %%
class Pizza(var crustSize: CrustSize=MediumCrust, 
            var crustType: CrustType=ThickCrust) {
    val toppings = scala.collection.mutable.ArrayBuffer[Topping]()
    
    def addTopping(t: Topping): Unit = toppings += t
    def removeTopping(t: Topping): Unit = toppings -= t
    def removeAllToppings(): Unit = toppings.clear()
}
// Out:
// defined class Pizza
