// %%
var text = ""
try {
  text = openAndReadFile(path)
} catch {
  case e: FileNotFoundException => println(s"No such file: $path")
  case e: IOException => println(
      s"IO Exception attemting to read from $path")
  case _: Throwable => println(s"Unexpected error reading $path")
} finally {
  println("...and moving right along")
}
