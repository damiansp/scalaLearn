// %%
// Lists, Sets, Maps
val numbers = List(1, 1, 2, 3, 5, 8, 13)
val colors = List("red", "green", "blue")
// Out:
// numbers: List[Int] = List(1, 1, 2, 3, 5, 8, 13)
// colors: List[String] = List("red", "green", "blue")

// %%
println(s"I Have ${colors.size} colors: $colors")
println(colors.head)
println(colors.tail)
println(colors(1))
// Out:
// I Have 3 colors: List(red, green, blue)
// red
// List(green, blue)
// green

// %%
var total = 0

for (i <- numbers) total += i
println(total)

for (c <- colors) println(c)
colors.foreach((c: String) => println(c))
// Out:
// 33
// red
// green
// blue
// red
// green
// blue
// total: Int = 33

// %%
val sizes = colors.map((c: String) => c.size)
println(sizes)

val total2 = numbers.reduce((a: Int, b: Int) => a + b)
println(total2)
// Out:
// List(3, 5, 4)
// 33
// sizes: List[Int] = List(3, 5, 4)
// total2: Int = 33

// %%
val colorMap = Map("red" -> 0xFF0000, "green" -> 0xFF00, "blue" -> 0xFF)
val redHex = colorMap("red")
val cyanHex = colorMap("green") | colorMap("blue")
val hasWhite = colorMap.contains("white")
println(redHex)
println(cyanHex)
println(hasWhite)

for (pairs <- colorMap) println(pairs)
// Out:
// 16711680
// 65535
// false
// (red,16711680)
// (green,65280)
// (blue,255)
// colorMap: Map[String, Int] = Map(
//   "red" -> 16711680,
//   "green" -> 65280,
//   "blue" -> 255
// )
// redHex: Int = 16711680
// cyanHex: Int = 65535
// hasWhite: Boolean = false

// %%
// What's in a List?
